# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
train_npy_path = '/home/btang5/work/2025/latent-diffusion/workspace/lsun/lsun_churches_train.npy'

train_npy = np.load(train_npy_path)

# %%
size_bytes = train_npy.nbytes
print(f"{size_bytes / 1024**3:.2f} GiB")
# Out:
# 22.20 GiB

# %%
# Visualize
idx = 1 # random

image = train_npy[idx] 
print(image.shape)
plt.imshow(image)
# Out:
# (256, 256, 3)

# %%
val_npy_path = '/home/btang5/work/2025/latent-diffusion/workspace/lsun/lsun_churches_val.npy'


val_npy = np.load(val_npy_path)

size_bytes = val_npy.nbytes

print(f"{size_bytes/1024**3:.2f}GB")

# Visualize
idx = 1 # random

image = val_npy[idx] 
print(image.shape)
plt.imshow(image)
# Out:
# 0.92GB
# (256, 256, 3)
